# %%
import pandas as pd
# df = pd.read_excel("data/raw/Observations 2012-2025.xlsx")

df_species = pd.read_excel("data/raw/Observations 2012-2025.xlsx", sheet_name="ESPECES")
df_sites = pd.read_excel("data/raw/Observations 2012-2025.xlsx", sheet_name="GPS-MILIEU")
df_observations = pd.read_excel("data/raw/Observations 2012-2025.xlsx", sheet_name="NOM FRANÇAIS")

# %%
df_species.head()
# Out:
#    Unnamed: 0  Unnamed: 1          Aigrette bleue  \
# 0         NaN         NaN       Aigrette garzette
# 1         NaN         NaN       Aigrette neigeuse
# 2         NaN         NaN      Aigrette tricolore
# 3         NaN         NaN          Amazone aourou
# 4         NaN         NaN  Astrild à joues orange
#
#               Egretta caerulea                      Migrateur
# 0             Egretta garzetta                      Migrateur
# 1                Egretta thula                      Migrateur
# 2  Egretta tricolor ruficollis                      Migrateur
# 3            Amazona amazonica  Exogène introduit par l'homme
# 4             Estrilda melpoda                            NaN

# %%
df_sites.head()
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2 WGS84 UTM 20 Unnamed: 4 Unnamed: 5  \
# 0         NaN         NaN   Transect            X          Y        NaN
# 1         NaN         NaN   Aéroport       714593    1614233   Mangrove
# 2         NaN         NaN   Aéroport       714416    1614194   Mangrove
# 3         NaN         NaN   Aéroport       714133    1614141   Mangrove
# 4         NaN         NaN   Aéroport       713914    1614103   Mangrove
#
#   Unnamed: 6 Unnamed: 7
# 0        NaN        NaN
# 1         S1       SIPI
# 2         S1       S1P2
# 3         S1       S1P3
# 4         S1       S1P4

# %%
df_observations.head()
# Out:
#   Nom observateur  code département  Nom transect                 date  \
# 0             NaN               NaN           NaN                  NaN
# 1             NaN               NaN           NaN                  NaN
# 2    BELFAN David             972.0  Fond l'Etang  2014-04-12 00:00:00
# 3    BELFAN David             972.0  Fond l'Etang  2014-04-12 00:00:00
# 4    BELFAN David             972.0  Fond l'Etang  2014-04-12 00:00:00
#
#    1er, 2e ou 3e passage nuages  pluie  vent  visibilité  N° point  ...  \
# 0                    NaN    NaN    NaN   NaN         NaN       NaN  ...
# 1                    NaN    NaN    NaN   NaN         NaN       NaN  ...
# 2                    1.0      2    1.0   1.0         1.0       1.0  ...
# 3                    1.0      2    1.0   1.0         1.0       1.0  ...
# 4                    1.0      2    1.0   1.0         1.0       1.0  ...
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20   totaux  \
# ...
